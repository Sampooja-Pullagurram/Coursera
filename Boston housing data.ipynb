# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import statsmodels.api as sm
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\EJGMR\OneDrive - Bayer\Downloads\boston_housing.csv")

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  LSTAT    506 non-null    float64
#  12  MEDV     506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
df.shape
# Out:
# (506, 13)

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.hist(bins=50, width=1, figsize=(20,10))
plt.suptitle('Feature Distribution', x=0.5, y=1.02, ha='center', fontsize='large')
plt.tight_layout()
plt.show()

# %%
plt.figure( figsize= (20,10))
plt.suptitle('Pairplots', ha='center', fontsize='large')
sns.pairplot(df.sample(250))
plt.show()

# %% [markdown]
# # Generate Descriptive Statistics and Visualizations

# %%
plt.figure(figsize=(5,3))
sns.boxplot(y=df.MEDV)
plt.title('Boxplot for MEDV')
plt.show()

# %% [markdown]
# presence of outliers

# %%
plt.figure(figsize=(3,2))
sns.displot(x=df.CHAS)
plt.title('Bar plot for the Charles river')
plt.show()

# %% [markdown]
# Charles River majorly not bounded by tract

# %%
df.loc[(df.AGE <=35), 'Age_group'] = '35 years and younger'
df.loc[(df.AGE >=70), 'Age_group'] = '70 years and older'
df.loc[(df.AGE >35) & (df.AGE <70), 'Age_group'] = 'between 35 and 70 years'
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV                Age_group
# 0       15.3   4.98  24.0  between 35 and 70 years
# ...

# %%
plt.figure(figsize=(10,2))
sns.boxplot(x=df.Age_group, y=df.MEDV, data=df)
plt.title('Boxplot for the MEDV variable vs the AGE variable')
plt.show()

# %% [markdown]
# 35 yeras and younger age group pays the higest median house price while 70 years and older age group opts for lowest median house price

# %%
x=df.NOX
y=df.INDUS
plt.figure(figsize=(8,3))
plt.scatter(x,y)
plt.xlabel('NOX')
plt.ylabel('INDUS')
plt.title('Relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town')
plt.show()

# %% [markdown]
# It seems to show a linear relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town

# %%
plt.figure(figsize=(5,3))
plt.hist(x=df.PTRATIO, bins=10, width=0.8)
plt.title('Histogram for the pupil to teacher ratio variable')
plt.xlabel('PTRATIO')
plt.show()

# %% [markdown]
# Pupil to teacher ratio is highest between 20-21 range

# %% [markdown]
# # Use the appropriate tests to answer the questions

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV                Age_group
# 0       15.3   4.98  24.0  between 35 and 70 years
# ...

# %% [markdown]
# # Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)

# %% [markdown]
# Null hypothesis: There is no difference in average Median value of houses bounded & unbounded by the Charles river

# %% [markdown]
# Alternate hypothesis: There is a difference in average Median value of houses bounded & unbounded by the Charles river

# %%
df.CHAS.value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
a=df[df.CHAS == 0]['MEDV']
a
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 471, dtype: float64

# %%
b=df[df.CHAS == 1]['MEDV']
b
# Out:
# 142    13.4
# 152    15.3
# 154    17.0
# 155    15.6
# 160    27.0
# 162    50.0
# 163    50.0
# 208    24.4
# 209    20.0
# 210    21.7
# 211    19.3
# 212    22.4
# 216    23.3
# 218    21.5
# 219    23.0
# 220    26.7
# 221    21.7
# 222    27.5
# 234    29.0
# 236    25.1
# 269    20.7
# 273    35.2
# 274    32.4
# 276    33.2
# 277    33.1
# 282    46.0
# 283    50.0
# 356    17.8
# 357    21.7
# 358    22.7
# 363    16.8
# 364    21.9
# 369    50.0
# 370    50.0
# 372    50.0
# Name: MEDV, dtype: float64

# %%
print(a.mean(), b.mean())
# Out:
# 22.093842887473464 28.439999999999998

# %%
scipy.stats.ttest_ind(a,b)
# Out:
# Ttest_indResult(statistic=-3.996437466090509, pvalue=7.390623170519905e-05)

# %% [markdown]
# Since p-value less than alpha value of 0.05, we will reject null hypothesis. Therefore there is a statistical significance difference in average Median value of houses bounded & unbounded by the Charles river

# %% [markdown]
# # Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)

# %% [markdown]
# Null hypothesis: There is no difference in average Median value of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)

# %% [markdown]
# Alternate hypothesis: Atleast one of the average Median value of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE) differs

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV                Age_group
# 0       15.3   4.98  24.0  between 35 and 70 years
# ...

# %%
low=df[df.Age_group == '35 years and younger']['MEDV']
mid=df[df.Age_group == 'between 35 and 70 years']['MEDV']
high=df[df.Age_group == '70 years and older']['MEDV']

# %%
f_statistic, p_value = scipy.stats.f_oneway(low, mid, high)
print('f_statistics={0}, p_value{1}'.format(f_statistic, p_value))
# Out:
# f_statistics=36.40764999196599, p_value1.7105011022702984e-15

# %% [markdown]
# Since p_value is less than alpha value of 0.05, we will reject null hypothesis. Therefore atleast one of the average Median value of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE) differs

# %% [markdown]
# # Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)

# %% [markdown]
# Null hypothesis: There is no correlation between NOX and INDUS

# %% [markdown]
# Alternate hypothesis: There is a correlation between NOX and INDUS

# %%
pearson, p_value = scipy.stats.pearsonr(df.NOX, df.INDUS)
print('Pearson coefficient={0}, p_value={1}'.format(pearson, p_value))
# Out:
# Pearson coefficient=0.763651446920915, p_value=7.913361061239593e-98

# %% [markdown]
# Since p_value is less than alpha value of 0.05, we will reject null hypothesis.Therefore there exists a relationship between NOX and INDUS

# %% [markdown]
# # What is the impact of an additional weighted distance  to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)

# %%
x=df.DIS

# %%
y=df.MEDV

# %%
x=sm.add_constant(x)

# %%
model=sm.OLS(y,x).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Fri, 12 Apr 2024   Prob (F-statistic):           1.21e-08
# Time:                        09:32:57   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...

# %%
correlation_coefficient=np.sqrt(0.062)
correlation_coefficient
# Out:
# 0.24899799195977465

# %% [markdown]
# square root of R-squared is 0.25, which implies there is weak correlation between DIS & MEDV

# %% [markdown]
# # correlation

# %%
c=df.corr(numeric_only = True)
c
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(c, annot=True, linewidth=2,cbar=False, fmt='0.2f')
plt.show()
